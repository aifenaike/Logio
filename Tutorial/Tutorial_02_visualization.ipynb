# %% [markdown]
# ## Tutorial Notebook for logplot module.
# The logplot module is used for plotting well logs in a physically appealing way.

# %% [markdown]
# ### Import Libraries

# %%
import sys
sys.path.append('..')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## plot_well

# %% [markdown]
# ### Generate random well log data
# - For our purpose, I assume a well with a total depth of 200ft, with 8.5in hole size and with some washouts. Since I have only generated random numbers for each log with no dependence from one log to another, these numbers have no physical meaning whatsoever. **This is only for display purpose!**

# %%
# Choose a random name for the well. Maybe not so random ;)!
well_name = 'Akintola-FA-01'
np.random.seed(1234)
# Generate a depth index
depth = np.arange(0,201,1)

# Generate a caliper log. 
cal = np.empty(201)
cal.fill(8.5)
noise = np.random.normal(0, .1, cal.shape) # Add noise to caliper log
cal = cal + noise
washout = np.random.uniform(0, 1, size=cal[0:5].shape) # Add washout
cal[20:25] = cal[20:25] + washout
cal[70:75] = cal[70:75] + washout

# Generate a Gamma log
gam = np.random.randint(0, 150, size=201)

# Generate a Resistivity log
res = np.random.uniform(0.2, 200, size=(201,))

# Generate a Density log
den = np.random.uniform(0.95, 2.95, size=(201,))

# Generate a Neutron Porosity log
neu = np.random.uniform(-0.15, 0.45, size=(201,))

# %% [markdown]
# ### Combine well logs into a dataframe

# %%
# Create empty dataframe to hold well logs
well_data = pd.DataFrame([])

# Assign log data to columns in well dataframe
well_data['DEPTH'] = depth
well_data['CALI'] = cal
well_data['GR'] = gam
well_data['RT'] = res
well_data['RHOB'] = den
well_data['NPHI'] = neu

# Display first 5 rows of dataframe
well_data.head()
# Out:
#    DEPTH      CALI  GR          RT      RHOB      NPHI
# 0      0  8.547144   2   72.167735  2.910654  0.111806
# 1      1  8.380902  35   42.317288  2.404075  0.152667
# 2      2  8.643271  46   92.899688  2.493826  0.309681
# 3      3  8.468735  38  180.200580  2.279375  0.285915
# 4      4  8.427941  58   58.405853  2.416415  0.346223

# %%
#import logplot module for well log visualization
from logio.logplot import PlotWell

log=["CALI",'GR','RT',"RHOB","NPHI"]
viz=PlotWell(dataset=well_data,depth=well_data['DEPTH'],
            name_of_well=well_name, depth_range =(0,200),logs=log)
viz.show()

# %% [markdown]
# ### Using real well log data read through speui package.

# %% [markdown]
# #### Plot from a csv file.

# %%
# Choose a random name for the well.
well_name = 'Stavanger-BB-01'

#import core module to read data file
from logio.core import Analysis
instance = Analysis()
well_data =instance.read_file(filename="data/wellx1.csv")
well_data = well_data.dropna()

# %%
log=["CALI",'GR','RT',"RHOB","NPHI","DT"]
viz=PlotWell(dataset=well_data,depth=well_data['DEPTH'],
            name_of_well=well_name, depth_range =(3200,3400),logs=log)
viz.show()

# %% [markdown]
# #### Plot from a LAS file

# %%
data =instance.read_file(filename="data/15_9-F-11A.LAS")
data = data.dropna()

# %%
##Visualize the following logs: Caliper, Gamma-ray, Resistivity, Density, Neutron logs
log_to_show=["CALI",'GR','RT',"RHOB","NPHI"]
viz=PlotWell(dataset=data,depth=data['DEPTH'],
            name_of_well="WELL_11_A_15", depth_range =(3225,3350),logs=log_to_show)
viz.show()

# %%
##Visualize the following logs: Caliper, Gamma-ray, Resistivity, Density, Neutron and Sonic-logs
data =instance.read_file(filename="data/15_9-F-11B.LAS")
data = data.dropna()
log_to_show=["CALI",'GR','RT',"RHOB","NPHI"]
viz=PlotWell(dataset=data,depth=data['DEPTH'],
            name_of_well="WELL_11_B_15", depth_range =(3225,3350),logs=log_to_show)
viz.show()

# %% [markdown]
# ## plot_logs

# %%
from logio.logplot import LogPlot

# %%
instance = Analysis()
data =instance.read_file(filename="data/15_9-F-11B.LAS")
data = data.dropna()
viz= LogPlot(data)
data.columns
# Out:
# Index(['DEPTH', 'ABDCQF01', 'ABDCQF02', 'ABDCQF03', 'ABDCQF04', 'BS', 'CALI',
#        'DRHO', 'GR', 'NPHI', 'PEF', 'RACEHM', 'RACELM', 'RD', 'RHOB', 'RM',
#        'ROP', 'RPCEHM', 'RPCELM', 'RT'],
#       dtype='object')

# %%
log_to_show=["CALI",("RHOB","DRHO"),"GR","ROP","NPHI","PEF"]
viz.plot_log(y="DEPTH", plots=log_to_show,y_range=(3225,3350), xscale =['linear'],figsize=(10,10))

# %% [markdown]
# #### visualizing Gamma-ray log with a cutoff value.
# Using Gamma-ray log as a case study:
# - There is an existence of more natural radioactivity in shales than sands. Hence, It is expected that the GR reading in shales to be higher than in sand
# - The cutoff is basically a GR value above which you would categorize such region as a shale, and below it as sand.
# - The `cutoff_plot` is a way of visualising those regions easily, by specifying what your cutoff value is. Similar applications can be extend to interprete other logs.

# %%
viz.cutoff_plot(x="GR", y="DEPTH", x_cutoff=0.45,  y_range= (0,0),xscale='linear',
                labels= ['Sand', 'Shale'], fig_size = (4.5, 7),colors=['#964B00','#101010'])

# %%
viz.cutoff_plot(x="GR", y="DEPTH", x_cutoff=0.45,  y_range= (0,0),xscale='log',
                labels= ['Sand', 'Shale'], fig_size = (4.5, 10),colors=['#964B00','#101010'])
